# %%
import pandas as pd

# %%
import numpy as np

# %%
taxi_df = pd.read_parquet('Data/yellow_tripdata_2019-02.parquet')

# %%
taxi_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-02-01 00:59:04   2019-02-01 01:07:27              1.0
# 1         1  2019-02-01 00:33:09   2019-02-01 01:03:58              1.0
# 2         1  2019-02-01 00:09:03   2019-02-01 00:09:16              1.0
# 3         1  2019-02-01 00:45:38   2019-02-01 00:51:10              1.0
# 4         1  2019-02-01 00:25:30   2019-02-01 00:28:14              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.1         1.0                  N            48           234
# 1            9.8         1.0                  N           230            93
# 2            0.0         1.0                  N           145           145
# 3            0.8         1.0                  N            95            95
# 4            0.8         1.0                  N           140           263
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
taxi_df.shape
# Out:
# (7049370, 19)

# %%
taxi_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
taxi_df = taxi_df[['tpep_pickup_datetime','tpep_dropoff_datetime','passenger_count','trip_distance','RatecodeID','PULocationID','DOLocationID','payment_type','total_amount','airport_fee']]

# %%
taxi_df.shape
# Out:
# (7049370, 10)

# %%
taxi_df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-02-01 00:59:04   2019-02-01 01:07:27              1.0            2.1
# 1  2019-02-01 00:33:09   2019-02-01 01:03:58              1.0            9.8
# 2  2019-02-01 00:09:03   2019-02-01 00:09:16              1.0            0.0
# 3  2019-02-01 00:45:38   2019-02-01 00:51:10              1.0            0.8
# 4  2019-02-01 00:25:30   2019-02-01 00:28:14              1.0            0.8
#
#    RatecodeID  PULocationID  DOLocationID  payment_type  total_amount  \
# 0         1.0            48           234             1          12.3
# 1         1.0           230            93             2          33.3
# 2         1.0           145           145             2           3.8
# 3         1.0            95            95             2           6.8
# 4         1.0           140           263             2           6.3
#
#   airport_fee
# 0        None
# 1        None
# 2        None
# 3        None
# ...

# %%
taxi_df.hist(figsize=(20,10),bins=60);

# %%
taxi_df.reset_index().plot(kind='scatter',y ='total_amount',x='index',figsize=(10,6));

# %%
taxi_df[taxi_df['total_amount'] <1000].reset_index().plot(kind='scatter',y ='total_amount',x='index',figsize=(10,6));
